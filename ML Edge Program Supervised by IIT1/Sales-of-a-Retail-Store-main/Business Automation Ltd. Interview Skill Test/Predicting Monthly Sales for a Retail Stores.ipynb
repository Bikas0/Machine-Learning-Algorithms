# %% [markdown]
# # Dataset from Kaggle
#
# https://www.kaggle.com/datasets/piyushagni5/monthly-sales-of-french-champagne

# %% [markdown]
# # Import Library

# %%
# !pip install statsmodels --upgrade
# !pip install tensorflow
import warnings
import itertools
import numpy as np
import pandas as pd
import tensorflow as tf
import statsmodels.api as sm
from datetime import datetime
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
from statsmodels.tsa.arima.model import ARIMA
from pandas.tseries.offsets import DateOffset
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from keras.preprocessing.sequence import TimeseriesGenerator
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the Dataset

# %%
dataset = pd.read_csv("monthly_champagne_sales.csv")
dataset.head()
# Out:
#      Month  Sales
# 0  1964-01   2815
# 1  1964-02   2672
# 2  1964-03   2755
# 3  1964-04   2721
# 4  1964-05   2946

# %%
# Rename the columns name
dataset.rename(columns={"Month": "Date", "Sales": "Total_Sales"}, inplace = True)

# %%
# Information of the dataset such as number of samples, colmns, data type, Non-Null value and how much memory size use.
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         105 non-null    object
#  1   Total_Sales  105 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB

# %%
# Convert the date column to a datetime object and set it as the index
dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset.set_index('Date', inplace=True)
dataset.head()
# Out:
#             Total_Sales
# Date
# 1964-01-01         2815
# 1964-02-01         2672
# 1964-03-01         2755
# 1964-04-01         2721
# 1964-05-01         2946

# %%
dataset.shape
# Out:
# (105, 1)

# %%
# Check duplicate index
dataset.index.duplicated().sum()
# Out:
# 0

# %%
dataset.describe()
# Out:
#         Total_Sales
# count    105.000000
# mean    4761.152381
# std     2553.502601
# min     1413.000000
# 25%     3113.000000
# 50%     4217.000000
# 75%     5221.000000
# max    13916.000000

# %% [markdown]
# # Functions

# %%
def adfuller_test_function(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Data has no unit root and is stationary")
    else:
        print("Data indicating it's non-stationary ")

# %%
def plot_test_pred_function(model_name, prediction_value):
    plt.figure(figsize=(12,6))
    prediction_value.plot(linewidth=3,label = f"Prediction of {model_name}", c = 'r')
    test_data['Total_Sales'].plot(linewidth=3, label = "Sales of Test Data")
    plt.title(f'Prediction vs Test Data of {model_name} Model', color = 'm', size = 15, pad = 10)
    plt.ylabel("Sales")
    plt.xlabel("Date of Months")
    plt.legend()

# %%
def root_mean_square_error_function(model_name, prediction_value):
    print("Mean of Test Data: ", round(test_data["Total_Sales"].mean(), 2))
    root_mean_square_error = np.sqrt(mean_squared_error(test_data["Total_Sales"], prediction_value))
    return round(root_mean_square_error,2)
    #print(f"Mean Suare Error of {model_name} Model : ", round(root_mean_square_error,2))

# %%
def dataset_for_future_pred_plot_function(dataset, length_of_month_future_pred):
    future_date=[dataset.index[-1]+ DateOffset(months=x+1)for x in range(0,length_of_month_future_pred)]
    future_date_df=pd.DataFrame(index=future_date[0:],columns=dataset.columns)
    future_df=pd.concat([dataset,future_date_df])
    return future_df

# %%
def plot_pred_future_sales_with_previoue_sales_function(model_name, forcasting_column):
    colors = ['g', 'r']
    future_df[['Total_Sales', forcasting_column]].plot(color = colors, linewidth=3, figsize=(12,6)) 
    plt.xlabel("Date of Months")
    plt.ylabel("Sales")
    plt.title(f"Prediction of Future Data for {model_name}")

# %%
def predicted_data_function(num_of_months):
    predictions = []
    first_eval_batch = scaled_train[-n_input:]
    current_batch = first_eval_batch.reshape((1, -n_input, n_features))
    for i in range(num_of_months):
        current_pred = model.predict(current_batch)[0]
        predictions.append(current_pred)
        current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis = 1)
            
    return predictions

# %% [markdown]
# # Visualize the Data

# %%
dataset["Total_Sales"].plot(c = 'm', linewidth=3, figsize=(12,6))
plt.ylabel("Sales")
plt.xlabel("Date of Months")
plt.title("Monthly Sales of a Retail Store", pad = 10, c = 'r')
# Out:
# Text(0.5, 1.0, 'Monthly Sales of a Retail Store')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Check Missing Value of the dataset

# %%
dataset.isnull().sum()
# Out:
# Total_Sales    0
# dtype: int64

# %%
# Remove Null Value
# dataset = dataset.ffill() #interpolate()

# %% [markdown]
# Rolling/Moving Average for testing Stationary

# %%
dataset['rolling_avg'] = dataset.Total_Sales.rolling(12).mean()
colors = ['g', 'r']
dataset[["Total_Sales", "rolling_avg"]].plot(color=colors, linewidth=3, figsize=(12,6))
plt.title("Sales of a Retail Store for Simple Moving Average", pad = 10, c = 'm')
plt.xlabel('Date of Months')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# Dickey Fuller Test for testing Stationary

# %%
adfuller_test_function(dataset['Total_Sales'])
# Out:
# ADF Test Statistic : -1.833593056327623
# p-value : 0.363915771660245
# #Lags Used : 11
# Number of Observations Used : 93
# Data indicating it's non-stationary

# %% [markdown]
# Differencing for getting Stationary

# %%
dataset['Sales First Difference']=dataset['Total_Sales']-dataset['Total_Sales'].shift(1)

dataset['Seasonal First Difference']=dataset['Total_Sales']-dataset['Total_Sales'].shift(12)
dataset.head(15)
# Out:
#             Total_Sales  rolling_avg  Sales First Difference  \
# Date
# 1964-01-01         2815          NaN                     NaN
# 1964-02-01         2672          NaN                  -143.0
# 1964-03-01         2755          NaN                    83.0
# 1964-04-01         2721          NaN                   -34.0
# 1964-05-01         2946          NaN                   225.0
# 1964-06-01         3036          NaN                    90.0
# 1964-07-01         2282          NaN                  -754.0
# 1964-08-01         2212          NaN                   -70.0
# 1964-09-01         2922          NaN                   710.0
# 1964-10-01         4301          NaN                  1379.0
# 1964-11-01         5764          NaN                  1463.0
# 1964-12-01         7312  3478.166667                  1548.0
# 1965-01-01         2541  3455.333333                 -4771.0
# 1965-02-01         2475  3438.916667                   -66.0
# 1965-03-01         3031  3461.916667                   556.0
#
#             Seasonal First Difference
# Date
# 1964-01-01                        NaN
# 1964-02-01                        NaN
# 1964-03-01                        NaN
# 1964-04-01                        NaN
# 1964-05-01                        NaN
# 1964-06-01                        NaN
# 1964-07-01                        NaN
# 1964-08-01                        NaN
# 1964-09-01                        NaN
# 1964-10-01                        NaN
# 1964-11-01                        NaN
# 1964-12-01                        NaN
# 1965-01-01                     -274.0
# 1965-02-01                     -197.0
# 1965-03-01                      276.0

# %%
adfuller_test_function(dataset['Seasonal First Difference'].dropna()) # Check Stationary
# Out:
# ADF Test Statistic : -7.626619157213163
# p-value : 2.060579696813685e-11
# #Lags Used : 0
# Number of Observations Used : 92
# Data has no unit root and is stationary

# %%
dataset["Seasonal First Difference"].plot(linewidth=3, figsize=(12,6))
plt.title("Seasonal First Difference", pad = 10, c = 'm')
plt.ylabel("Sales")
plt.xlabel("Date of Months")
plt.grid()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(2,1,1)
fig = plot_acf(dataset['Seasonal First Difference'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(2,1,2)
fig = plot_pacf(dataset['Seasonal First Difference'].iloc[13:],lags=40,ax=ax2)

# %%
from pandas.plotting import lag_plot
fig, axes = plt.subplots(1, 4, figsize=(10,3), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate(axes.flatten()[:4]):
    lag_plot(dataset.Total_Sales, lag=i+1, ax=ax, c='firebrick')
    ax.set_title('Lag ' + str(i+1))

fig.suptitle('Lag Plots of Total Sales \n(Points get wide and scattered with increasing lag -> lesser correlation)\n', y=1.15)      
plt.show();

# %% [markdown]
# "Grid Search" to find the optimal set of parameters.

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
aic = []
params = []
param_seasonals = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(dataset["Seasonal First Difference"],
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            params.append(param)
            aic.append(results.aic)
            param_seasonals.append(param_seasonal)
        except:
            continue
            
print("\n\nOptimal Set of Parameters based on AIC: ")          
min_values_index_aic = np.argmin(aic)
print('SARIMA{}x{} - AIC:{}'.format(params[min_values_index_aic], param_seasonals[min_values_index_aic], aic[min_values_index_aic]))
# Out:
# SARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1511.2713844170698
# SARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1497.4352397678579
# SARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:1575.261238249959
# SARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:1317.1692257539469
# SARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1512.6366920013731
# SARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1499.2551126445428
# SARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:1349.3150462276506
# SARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1315.1974743765609
# SARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1505.458970282013
# SARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:1474.4403691246064
# SARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:1559.0691094630706
# SARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1300.1430544893065
# SARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1503.873328742843
# SARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:1475.086541859423
# SARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:1346.0030792811835
# SARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:1295.6356402566244
# SARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1542.8688000304508
# SARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1499.2979467142118
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:1608.1570514995587
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1336.397577625159
# SARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:1513.206003809421
# SARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1499.6616632424789
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:1361.6027282224495
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:1324.8960225662086
# SARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1505.4709918036747
# SARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:1452.9213938519536
# SARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:1548.5412171964535
# SARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1288.8643084287887
# SARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:1485.235487946565
# SARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1454.790463774408
# SARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:1338.277914987366
# SARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1284.3430737908582
# SARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1503.527291937002
# SARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1485.7810217781202
# SARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:1575.948091822538
# SARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:1315.8319181683776
# SARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:1485.0821853254745
# SARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1487.072024378371
# SARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:1329.6095116518252
# SARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:1311.1182407015017
# SARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1502.241480234549
# SARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:1469.318678194579
# SARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:1563.169452103669
# SARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:8.0
# SARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:1484.3360304883365
# SARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1470.8395104884883
# SARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:1331.5862521223032
# SARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:1296.973747185708
# SARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1526.2987605132853
# SARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1487.1767970856592
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1587.5995152153343
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1323.2907911246452
# SARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:1487.0652784077897
# SARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1488.8560776820295
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:1337.5082463926299
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1316.5446898562363
# SARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1504.2686469389262
# SARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1450.6690016416737
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1551.2737351801347
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1288.8593811242226
# SARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:1466.915892694379
# SARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1452.347913933403
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:1320.3109674550637
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1283.2367766307757
#
#
# Optimal Set of Parameters based on AIC:
# SARIMA(1, 0, 1)x(0, 1, 1, 12) - AIC:8.0

# %%
training_size = int(len(dataset)*0.9)
train_data, test_data = dataset[0:training_size],dataset[training_size:len(dataset)]

# %% [markdown]
# # Model Selection & Training

# %% [markdown]
# SARIMA Model

# %%
model=sm.tsa.statespace.SARIMAX(train_data['Total_Sales'],order=(1, 0, 1),seasonal_order=(1, 0, 1, 12))
results=model.fit()

# %%
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9091      0.090     10.104      0.000       0.733       1.085
# ma.L1         -0.5797      0.139     -4.164      0.000      -0.853      -0.307
# ar.S.L12       0.9687      0.024     40.027      0.000       0.921       1.016
# ma.S.L12      -0.1999      0.120     -1.663      0.096      -0.435       0.036
# sigma2      6.792e+05   1.03e+05      6.563      0.000    4.76e+05    8.82e+05
# ==============================================================================

# %%
prediction_SARIMA = results.predict(start=len(train_data),end=len(train_data)+len(test_data)-1,dynamic=True)

# %%
print("Test data vs Predicted Data\n")
for i in range(len(test_data)):
    print(f'{test_data["Total_Sales"][i]} ------ {prediction_SARIMA[i]}')
# Out:
# Test data vs Predicted Data
#
# 9851 ------ 10151.693748078056
# 12670 ------ 13127.855612729561
# 4348 ------ 4045.5817692358296
# 3564 ------ 3449.3825169032893
# 4577 ------ 4364.980875525557
# 4788 ------ 4680.45721939072
# 4618 ------ 4805.381465148255
# 5312 ------ 4826.598399535483
# 4298 ------ 4609.164157090211
# 1413 ------ 1848.891372864723
# 5877 ------ 5791.808000291281

# %%
plot_test_pred_function("SARIMA", prediction_SARIMA)

# %% [markdown]
# # Model Evaluation

# %%
rmse_sarima = root_mean_square_error_function("SARIMA", prediction_SARIMA)
print("Mean Suare Error of SARIMA Model : ", rmse_sarima)
# Out:
# Mean of Test Data:  5574.18
# Mean Suare Error of SARIMA Model :  305.4

# %% [markdown]
# # Future Sales Prediction of SARIMA Model

# %%
import datetime
def predict(y, m, d):
    last_date = datetime.date(2021, 12, 30)
    expected_date = datetime.date(y, m, d)
    day = expected_date - last_date
    date = day.days
    print(date)
    return date
    
#   pred_future = model.predict(start = len(data_value)+1, end = len(data_value)+x, dynamic = False)
#   pred_future = pred_future[-1:][0]
#   print(f"\n The prediction value of {d}/{m}/{y} is = {pred_future:.2f}")

year, month, day= [int(x) for x in input("Enter year/month/day values: ").split("-")]
predict(year, month, day)
# Out:
# Enter year/month/day values: 12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 14
#       8     return date
#      10 #   pred_future = model.predict(start = len(data_value)+1, end = len(data_value)+x, dynamic = False)
#      11 #   pred_future = pred_future[-1:][0]
#      12 #   print(f"\n The prediction value of {d}/{m}/{y} is = {pred_future:.2f}")
# ---> 14 year, month, day= [int(x) for x in input("Enter year/month/day values: ").split("-")]
#      15 predict(year, month, day)
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
num_of_months = int(input("Numbers of Months want to predict Future Sales : "))
future_df = dataset_for_future_pred_plot_function(dataset, num_of_months)
future_df

# %%
future_df['forecast'] = results.predict(start = len(dataset)-1, end = (len(dataset)-1 + num_of_months), dynamic= True) 
print(f"Future '{num_of_months}' month Sales of a Retail Stores: \n", future_df['forecast'][-num_of_months:])

# %%
plot_pred_future_sales_with_previoue_sales_function("SARIMA", 'forecast')

# %% [markdown]
# # LSTM Model

# %%
train_data = train_data.drop(["rolling_avg", "Sales First Difference",  "Seasonal First Difference"], axis = 1)
test_data = test_data.drop(["rolling_avg", "Sales First Difference",  "Seasonal First Difference"], axis = 1)

# %%
tf.keras.utils.set_random_seed(1)
# Data Scaling
scaler = MinMaxScaler()

# %%
scaler.fit(train_data)
scaled_train = scaler.transform(train_data)
scaled_test = scaler.transform(test_data)

# %%
n_input = 12 # As Seasonal
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length = n_input, batch_size= 1)

# %%
#Define Model
model = Sequential()
model.add(LSTM(100, activation = 'relu', input_shape = (n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer="adam", loss = 'mse')

# %%
model.summary()

# %%
#fit model
model.fit(generator, epochs = 600)

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)), loss_per_epoch, c = "r", label = "Loss")
plt.title('Loss per epoch', color = 'red', size = 15, pad = 10)
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")

# %%
last_train_batch = scaled_train[-n_input:]

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))
last_train_batch

# %%
model.predict(last_train_batch)

# %%
test_predictions = predicted_data_function(len(test_data))

# %%
predictions_LSTM = scaler.inverse_transform(test_predictions)

# %%
test_data["predictions_LSTM"] = predictions_LSTM
print("Test data vs Predicted Data\n")
for i in range(len(test_data)):
    print(f'{test_data["Total_Sales"][i]} ------ {test_data["predictions_LSTM"][i]}')

# %%
plot_test_pred_function("LSTM", test_data["predictions_LSTM"])

# %% [markdown]
# # Model Evaluation of LSTM Model

# %%
rmse_lstm = root_mean_square_error_function("LSTM", test_data["predictions_LSTM"])
print("Mean Suare Error of LSTM Model : ", rmse_lstm)

# %% [markdown]
# # Future months Sales Data

# %%
df = dataset.drop(["rolling_avg", "Sales First Difference", "Seasonal First Difference"], axis=1)

# %%
norm_df = scaler.fit_transform(df)
future_predictions = predicted_data_function(num_of_months)

# %%
predictions_LSTM_future = scaler.inverse_transform(future_predictions)

# %%
future_df = dataset_for_future_pred_plot_function(dataset, len(predictions_LSTM_future))

# %%
future_df['future_sales'] = ["NaN"] * len(future_df)
j = 0 
future_df['future_sales'].iloc[len(dataset)-1] = future_df["Total_Sales"][len(dataset)-1]
for i in range((len(dataset) + len(predictions_LSTM_future))):
    if i > len(dataset)-1:
        if future_df['future_sales'].iloc[i] is not None:
            future_df['future_sales'].iloc[i] = predictions_LSTM_future[j][0]
        j += 1

# %%
future_df['future_sales'] = pd.to_numeric(future_df['future_sales'], errors='coerce')

# %%
print(f"Future '{num_of_months}' month Sales of a Retail Stores: \n", future_df['future_sales'][-num_of_months:])
plot_pred_future_sales_with_previoue_sales_function("LSTM", 'future_sales')

# %% [markdown]
# # Final Prediction

# %% [markdown]
# Minimum root mean square error give us the best performance of the model. In this project, LSTM model is the best preformance model as it's RMSE value is less (323.89 < 529.56) than SARIMA model.

# %%
print("Test data vs Predicted Data of the Best Performance LSTM Model\n")
for i in range(len(test_data)):
    print(f'{test_data["Total_Sales"][i]} ------ {test_data["predictions_LSTM"][i]}')

# %%
plt.figure(figsize=(12,6))
prediction_SARIMA.plot(linewidth=3, label = f"SARIMA model RMSE : {rmse_sarima}", c = 'g')
test_data["predictions_LSTM"].plot(linewidth=3,label = f"LSTM model RMSE : {rmse_lstm}", c = 'r')
test_data['Total_Sales'].plot(linewidth=3, label = "Sales of Test Data")
plt.title(f'Best performing model based on RMSE between Prediction & Test Data', color = 'm', size = 15, pad = 10)
plt.ylabel("Sales")
plt.xlabel("Date of Months")
plt.legend()

# %% [markdown]
# # Classification and Future Work
